# %% [markdown]
# ## Task 1. Department wise performances

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#loading csv file using pandas
df=pd.read_csv(r"C:\Users\sachi\INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.csv")

# %%
#divide the data into various department
dp1=df.loc[(df['EmpDepartment']=="Sales")]
dp2=df.loc[(df['EmpDepartment']=="Development")] 
dp3=df.loc[(df['EmpDepartment']=="Research & Development")]
dp4=df.loc[(df['EmpDepartment']=="Human Resources")] 
dp5=df.loc[(df['EmpDepartment']=="Finance")]
dp6=df.loc[(df['EmpDepartment']=="Data Science")]

# %%
#spliting the discrete data values into several intervels
#spliting EmpHourlyRate
dp1["EmpHourlyRate"]=pd.cut(dp1["EmpHourlyRate"],[-1,30,40,50,60,70,80,90,100],
                           labels=["0-30","31-40","41-50","51-60","61-70","71-80","81-90","91-100"])
dp2["EmpHourlyRate"]=pd.cut(dp2["EmpHourlyRate"],[-1,30,40,50,60,70,80,90,100],
                           labels=["0-30","31-40","41-50","51-60","61-70","71-80","81-90","91-100"])
dp3["EmpHourlyRate"]=pd.cut(dp3["EmpHourlyRate"],[-1,30,40,50,60,70,80,90,100],
                           labels=["0-30","31-40","41-50","51-60","61-70","71-80","81-90","91-100"])
dp4["EmpHourlyRate"]=pd.cut(dp4["EmpHourlyRate"],[-1,30,40,50,60,70,80,90,100],
                           labels=["0-30","31-40","41-50","51-60","61-70","71-80","81-90","91-100"])
dp5["EmpHourlyRate"]=pd.cut(dp5["EmpHourlyRate"],[-1,30,40,50,60,70,80,90,100],
                           labels=["0-30","31-40","41-50","51-60","61-70","71-80","81-90","91-100"])
dp6["EmpHourlyRate"]=pd.cut(dp6["EmpHourlyRate"],[-1,30,40,50,60,70,80,90,100],
                           labels=["0-30","31-40","41-50","51-60","61-70","71-80","81-90","91-100"])

#spliting Experience Years In CurrentRole

dp1["ExperienceYearsInCurrentRole"]=pd.cut(dp1["ExperienceYearsInCurrentRole"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp2["ExperienceYearsInCurrentRole"]=pd.cut(dp2["ExperienceYearsInCurrentRole"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp3["ExperienceYearsInCurrentRole"]=pd.cut(dp3["ExperienceYearsInCurrentRole"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp4["ExperienceYearsInCurrentRole"]=pd.cut(dp4["ExperienceYearsInCurrentRole"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp5["ExperienceYearsInCurrentRole"]=pd.cut(dp5["ExperienceYearsInCurrentRole"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp6["ExperienceYearsInCurrentRole"]=pd.cut(dp6["ExperienceYearsInCurrentRole"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])

#spliting Distance From Home
dp1["DistanceFromHome"]=pd.cut(dp1["DistanceFromHome"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp2["DistanceFromHome"]=pd.cut(dp2["DistanceFromHome"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp3["DistanceFromHome"]=pd.cut(dp3["DistanceFromHome"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp4["DistanceFromHome"]=pd.cut(dp4["DistanceFromHome"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp5["DistanceFromHome"]=pd.cut(dp5["DistanceFromHome"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp6["DistanceFromHome"]=pd.cut(dp6["DistanceFromHome"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])

#spliting Employee Last Salary Hike Percentage
dp1["EmpLastSalaryHikePercent"]=pd.cut(dp1["EmpLastSalaryHikePercent"],[-1,10,15,20,25],
                           labels=["0-10","10-15","16-20","20-25"])
dp2["EmpLastSalaryHikePercent"]=pd.cut(dp2["EmpLastSalaryHikePercent"],[-1,10,15,20,25],
                           labels=["0-10","10-15","16-20","20-25"])
dp3["EmpLastSalaryHikePercent"]=pd.cut(dp3["EmpLastSalaryHikePercent"],[-1,10,15,20,25],
                           labels=["0-10","10-15","16-20","20-25"])
dp4["EmpLastSalaryHikePercent"]=pd.cut(dp4["EmpLastSalaryHikePercent"],[-1,10,15,20,25],
                           labels=["0-10","10-15","16-20","20-25"])
dp5["EmpLastSalaryHikePercent"]=pd.cut(dp5["EmpLastSalaryHikePercent"],[-1,10,15,20,25],
                           labels=["0-10","10-15","16-20","20-25"])
dp6["EmpLastSalaryHikePercent"]=pd.cut(dp6["EmpLastSalaryHikePercent"],[-1,10,15,20,25],
                           labels=["0-10","10-15","16-20","20-25"])

#spliting Training Times Last Year

dp1["TrainingTimesLastYear"]=pd.cut(dp1["TrainingTimesLastYear"],[-1,0,1,2,3,6],
                           labels=["0","1","2","3","4-6"])
dp2["TrainingTimesLastYear"]=pd.cut(dp2["TrainingTimesLastYear"],[-1,0,1,2,3,6],
                           labels=["0","1","2","3","4-6"])
dp3["TrainingTimesLastYear"]=pd.cut(dp3["TrainingTimesLastYear"],[-1,0,1,2,3,6],
                           labels=["0","1","2","3","4-6"])
dp4["TrainingTimesLastYear"]=pd.cut(dp4["TrainingTimesLastYear"],[-1,0,1,2,3,6],
                           labels=["0","1","2","3","4-6"])
dp5["TrainingTimesLastYear"]=pd.cut(dp5["TrainingTimesLastYear"],[-1,0,1,2,3,6],
                           labels=["0","1","2","3","4-6"])
dp6["TrainingTimesLastYear"]=pd.cut(dp6["TrainingTimesLastYear"],[-1,0,1,2,3,6],
                           labels=["0","1","2","3","4-6"])

#spliting Years Since Last Promotion

dp1["YearsSinceLastPromotion"]=pd.cut(dp1["YearsSinceLastPromotion"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp2["YearsSinceLastPromotion"]=pd.cut(dp2["YearsSinceLastPromotion"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp3["YearsSinceLastPromotion"]=pd.cut(dp3["YearsSinceLastPromotion"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp4["YearsSinceLastPromotion"]=pd.cut(dp4["YearsSinceLastPromotion"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp5["YearsSinceLastPromotion"]=pd.cut(dp5["YearsSinceLastPromotion"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])
dp6["YearsSinceLastPromotion"]=pd.cut(dp6["YearsSinceLastPromotion"],[-1,1,2,5,10,60],
                           labels=["0-1","1-2","3-5","6-10","10+"])

# %% [markdown]
# #### LETS CHECK IMPORTANT PERFORMANCE METRICS IN EACH DEPARTMENT
# **AGE**

# %%
sns.displot(x = "Age", hue = "PerformanceRating", data = dp1,kde = True,palette = ["#D5273E","DeepSkyBlue","Red"]).set(title='AGE AND PERFORMANCE OF SALES DEPT')
sns.displot(x = "Age", hue = "PerformanceRating", data = dp2,kde = True,palette = 'pastel').set(title='AGE AND PERFORMANCE OF DEVELOPMENT DEPT')
sns.displot(x = "Age", hue = "PerformanceRating", data = dp3,kde = True,palette=["#D5273E","#316B56","#FF6600"]).set(title='AGE AND PERFORMANCE OF REASEARCH & DEVELOPMENT DEPT')
sns.displot(x = "Age", hue = "PerformanceRating", data = dp4,kde = True,palette = 'pastel').set(title='AGE AND PERFORMANCE OF HUMAN RESOURCE DEPT')
sns.displot(x = "Age", hue = "PerformanceRating", data = dp5,kde = True,palette=["DeepSkyBlue","#B93D6F","#EEBF69"]).set(title='AGE AND PERFORMANCE OF FINANCE DEPT')
sns.displot(x = "Age", hue = "PerformanceRating", data = dp6,kde = True,palette=["DeepSkyBlue","#B93D6F","#EEBF69"]).set(title='AGE AND PERFORMANCE OF DATA SCIENCE DEPT')

# %% [markdown]
# * In sales department performance was high upto 35,performance keeps falling when age increases..Grade 4 employees are very less in the age group of more than 35..
# * In research & development departemnt percentage of waek performers (Grade 2 employees) are equally high in all age groups,how ever 80% of employees performing well in this department
# * In finance department weak performers are 30% moslty seen in very age group..But weak perfomers are increasing when the increases..
# * In HR department Grade 2 employees are high in 30 to 40 age group..Grade 4 employees are less in numbers from Hr department and Data science department

# %% [markdown]
# **Job Role,Education level,Hourly rate  and Performance of employees in variuos departments**

# %%
black_grad = ['#100C07', '#3E3B39', '#6D6A6A', '#9B9A9C', '#CAC9CD']
pink_grad = ['#8A0030', '#BA1141', '#FF5C8A', '#FF99B9', '#FFDEEB']
plt.figure(figsize=(20,5))
c=['DeepSkyBlue','LightCoral','grey']
c2=["#B93D6F","DeepSkyBlue","#EEBF69"]

labels1=["CLASS 3","CLASS 2","CLASS 4"]
plt.suptitle('Employee Job role vs performance  rating of each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])

countplt = plt.subplot(1, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp1["EmpJobRole"],hue=dp1["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp1)
plt.tight_layout()
plt.legend(loc='upper right')
plt.xticks(rotation=90)

countplt = plt.subplot(1, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp2["EmpJobRole"],hue=dp2["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp2)
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()

countplt = plt.subplot(1, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp3["EmpJobRole"],hue=dp3["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp3)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp4["EmpJobRole"],hue=dp4["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp4)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp5["EmpJobRole"],hue=dp5["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp5)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp6["EmpJobRole"],hue=dp6["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp6)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

plt.figure(figsize=(20,5))
plt.suptitle('Hourly rate vs performance  rating of each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])
countplt = plt.subplot(2, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpHourlyRate', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp1);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpHourlyRate', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp2);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpHourlyRate', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp3);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpHourlyRate', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp4);   
plt.xticks(rotation=90)
plt.legend(loc='upper center')
plt.tight_layout()

countplt = plt.subplot(2, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpHourlyRate', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp5);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpHourlyRate', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp6);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

plt.figure(figsize=(20,5))
countplt = plt.subplot(3, 6, 1)
plt.suptitle('Educational level and  performance  rating of each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpEducationLevel', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp1);   
plt.tight_layout()
plt.legend(loc='upper left')

countplt = plt.subplot(3, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpEducationLevel', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp2);   
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(3, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpEducationLevel', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp3);  
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(3, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpEducationLevel', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp4);   
plt.tight_layout()
plt.legend(loc='upper right')
countplt = plt.subplot(3, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpEducationLevel', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp5);   
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(3, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpEducationLevel', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp6);   
plt.tight_layout()
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **Job,Environment,Employer relationship satisfaction of employees in each Department**

# %%
plt.figure(figsize=(20,5))
c=['DeepSkyBlue','LightCoral','grey']
c2=["#B93D6F","DeepSkyBlue","#EEBF69"]

labels1=["CLASS 3","CLASS 2","CLASS 4"]
plt.suptitle('Employee performance rating based on Envirnment Satisfaction', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])

countplt = plt.subplot(1, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp1["EmpEnvironmentSatisfaction"],hue=dp1["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp1)
plt.tight_layout()
plt.legend(loc='upper right')
plt.xticks(rotation=90)
 
countplt = plt.subplot(1, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp2["EmpEnvironmentSatisfaction"],hue=dp2["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp2)
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()

countplt = plt.subplot(1, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp3["EmpEnvironmentSatisfaction"],hue=dp3["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp3)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp4["EmpEnvironmentSatisfaction"],hue=dp4["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp4)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp5["EmpEnvironmentSatisfaction"],hue=dp5["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp5)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp6["EmpEnvironmentSatisfaction"],hue=dp6["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp6)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')
 
plt.figure(figsize=(20,5))
plt.suptitle('Employee performance rating based on Job Satisfaction', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])
countplt = plt.subplot(2, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobSatisfaction', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp1);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobSatisfaction', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp2);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobSatisfaction', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp3);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobSatisfaction', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp4);   
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()

countplt = plt.subplot(2, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobSatisfaction', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp5);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobSatisfaction', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp6);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')    

plt.figure(figsize=(20,5))
plt.suptitle('Employee performance rating based on Relationship Satisfaction', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])
countplt = plt.subplot(3, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpRelationshipSatisfaction', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp1);   
plt.tight_layout()
plt.legend(loc='upper center')

countplt = plt.subplot(3, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpRelationshipSatisfaction', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp2);   
plt.tight_layout()
plt.legend(loc='upper center')

countplt = plt.subplot(3, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpRelationshipSatisfaction', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp3);  
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(3, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpRelationshipSatisfaction', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp4);   
plt.tight_layout()
plt.legend(loc='upper center')
countplt = plt.subplot(3, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpRelationshipSatisfaction', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp5);   
plt.tight_layout()
plt.legend(loc='upper left')

countplt = plt.subplot(3, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpRelationshipSatisfaction', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp6);   
plt.tight_layout()
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# * Most of the weak performers are not satisfied with the working environment in all departments,but some employees who performed well in sales,Development,R&d and HR not satisfied with the environment
# * Weak performers in R&D,HR, and Finance satisfied well with thier job,However a large percentage of Grade 3 employees are less satisfied with the job
# * Relationship satisfaction is less in R&D and Finance department irrespective of performance,weak perfomers are satisfied with relationship in Finance department..Relationship dis-satisfaction percentage is high in grade in empployees in all department

# %% [markdown]
# **Distance from Home,Employee Job Involvement,Experience Years In Current Role of emplouyees in each department**

# %%
plt.figure(figsize=(20,5))
c=['DeepSkyBlue','LightCoral','grey']
c2=["#B93D6F","DeepSkyBlue","#EEBF69"]

labels1=["CLASS 3","CLASS 2","CLASS 4"]
plt.suptitle('Employee Experience Years In Current Role in each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])

countplt = plt.subplot(1, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp1["ExperienceYearsInCurrentRole"],hue=dp1["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp1)
plt.tight_layout()
plt.legend(loc='upper right')
plt.xticks(rotation=90)
 
countplt = plt.subplot(1, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp2["ExperienceYearsInCurrentRole"],hue=dp2["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp2)
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()

countplt = plt.subplot(1, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp3["ExperienceYearsInCurrentRole"],hue=dp3["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp3)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp4["ExperienceYearsInCurrentRole"],hue=dp4["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp4)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp5["ExperienceYearsInCurrentRole"],hue=dp5["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp5)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp6["ExperienceYearsInCurrentRole"],hue=dp6["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp6)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')
 
plt.figure(figsize=(20,5))
plt.suptitle('Employee Job Involvement in each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])
countplt = plt.subplot(2, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobInvolvement', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp1);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobInvolvement', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp2);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobInvolvement', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp3);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobInvolvement', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp4);   
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()

countplt = plt.subplot(2, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobInvolvement', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp5);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='EmpJobInvolvement', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp6);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')    

plt.figure(figsize=(20,5))
plt.suptitle('Employee Distance From Home in each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])
countplt = plt.subplot(3, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='DistanceFromHome', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp1);   
plt.tight_layout()
plt.legend(loc='upper center')

countplt = plt.subplot(3, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='DistanceFromHome', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp2);   
plt.tight_layout()
plt.legend(loc='upper center')

countplt = plt.subplot(3, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='DistanceFromHome', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp3);  
plt.tight_layout()
plt.legend(loc='upper center')

countplt = plt.subplot(3, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='DistanceFromHome', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp4);   
plt.tight_layout()
plt.legend(loc='upper center')
countplt = plt.subplot(3, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='DistanceFromHome', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp5);   
plt.tight_layout()
plt.legend(loc='upper center')

countplt = plt.subplot(3, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='DistanceFromHome', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp6);   
plt.tight_layout()
plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# * Freshers are wroking well in all departments,weak performers are high in sales and finance who have an experience of 6 to 10..In R&D department as the experience increases Grade 4 performers were decreasing also weak performers in increasing in this dept
# * Job involvement is moderate or high in all department,Although job involvement is 3 or more weak performers are more common in Huamn Resource and Finance department
# * Emplooyees who got the rating of 2 in sales,R&D and Fianacne departments mostly travelling more than 5kms(oneside) perday..But the rest of the department employees distance that much affecting the performance

# %% [markdown]
# **Employee Last Salary Hike Percentage,Training Times Last Year and Attrition rate in each department**

# %%
plt.figure(figsize=(20,5))
c=['DeepSkyBlue','LightCoral','grey']
c2=["#B93D6F","DeepSkyBlue","#EEBF69"]

labels1=["CLASS 3","CLASS 2","CLASS 4"]
plt.suptitle('Employee Last Salary Hike Percentage in each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])

countplt = plt.subplot(1, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp1["EmpLastSalaryHikePercent"],hue=dp1["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp1)
plt.tight_layout()
plt.legend(loc='upper right')
plt.xticks(rotation=90)
 
countplt = plt.subplot(1, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp2["EmpLastSalaryHikePercent"],hue=dp2["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp2)
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()

countplt = plt.subplot(1, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp3["EmpLastSalaryHikePercent"],hue=dp3["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp3)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp4["EmpLastSalaryHikePercent"],hue=dp4["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp4)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp5["EmpLastSalaryHikePercent"],hue=dp5["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp5)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp6["EmpLastSalaryHikePercent"],hue=dp6["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp6)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')
 
plt.figure(figsize=(20,5))    
plt.suptitle('Employee Training Times Last Year in each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])
countplt = plt.subplot(2, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='TrainingTimesLastYear', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp1);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='TrainingTimesLastYear', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp2);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='TrainingTimesLastYear', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp3);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='TrainingTimesLastYear', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp4);   
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()

countplt = plt.subplot(2, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='TrainingTimesLastYear', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp5);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(2, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='TrainingTimesLastYear', hue='PerformanceRating',palette=["#D5273E","DeepSkyBlue","#FFEA00"], data=dp6);   
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')    

plt.figure(figsize=(20,5))
plt.suptitle('Attrition in each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])
countplt = plt.subplot(3, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='Attrition', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp1);   
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(3, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='Attrition', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp2);   
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(3, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='Attrition', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp3);  
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(3, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='Attrition', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp4);   
plt.tight_layout()
plt.legend(loc='upper right')
countplt = plt.subplot(3, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='Attrition', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp5);   
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(3, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x='Attrition', hue='PerformanceRating',palette=["#D5273E","Blue","#FFEA00"], data=dp6);   
plt.tight_layout()
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# * Salary hike will differ based on job roles,but most of the grade 3 performers got a hike of 10% to 15%...Most of the grade 4 employees got 20 to 25% hike,but in sales and finance department some perncentage of weak employees also got a hike of more than 15%..
# * Trainings are beneficial in all departments,but periodic trainings are necessary for employees to update,strengthen skills and perform more efficient..Sales and Development departments conducted more trainings but that not seems to be fully beneficial to sales department..Most of the Grade 4 employees attended more than 2 trainings last year..
# * Attrition rate is low in all departments,but out of 15% left the company 10% employees are Grade 3 employees

# %% [markdown]
# **Years Since Last Promotion of employees in each department**

# %%
plt.figure(figsize=(20,5))
c=['DeepSkyBlue','LightCoral','grey']
c2=["#B93D6F","DeepSkyBlue","#EEBF69"]

labels1=["CLASS 3","CLASS 2","CLASS 4"]
plt.suptitle('Years Since Last Promotion of employees in each department', fontweight='heavy', 
             fontsize='18', fontfamily='sans-serif', color=black_grad[0])

countplt = plt.subplot(1, 6, 1)
plt.title('Sales', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp1["YearsSinceLastPromotion"],hue=dp1["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp1)
plt.tight_layout()
plt.legend(loc='upper right')
plt.xticks(rotation=90)

countplt = plt.subplot(1, 6, 2)
plt.title('Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp2["YearsSinceLastPromotion"],hue=dp2["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp2)
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()

countplt = plt.subplot(1, 6, 3)
plt.title('Research & Development', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp3["YearsSinceLastPromotion"],hue=dp3["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp3)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 4)
plt.title('Human resource', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp4["YearsSinceLastPromotion"],hue=dp4["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp4)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 5)
plt.title('Finance', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp5["YearsSinceLastPromotion"],hue=dp5["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp5)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')

countplt = plt.subplot(1, 6, 6)
plt.title('Data Science', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
ax=sns.countplot(x=dp6["YearsSinceLastPromotion"],hue=dp6["PerformanceRating"],palette=["#D5273E","#316B56","#FF6600"],data=dp6)
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# * Most of the Grade 3 and Grade 4 employees got a promotion in the last year in evrey department
# * A high number of Grade 2 employees in the Finance also got a promotion last year

# %% [markdown]
# ### DEPARTMENT WISE PERFORMANCE REPORT

# %% [markdown]
# #### Development-
#   Overall Development department performs highly among all other departments..
# * The department utilizing its work force efficiently and effectively irrespective of age group (Grade 2 employees are very less 1.1%)..
# * Most of the employees have a bachelor's or masters degree for thier job role.
# * Job involvment is high in this department and most of the employees have an experience of atleast 2 years ...
# * Employees are higly satisfied with this job role and employer relationship,but a good percentage of Grade 3 and 4 employees are not..
# * Distance is not creating any performance differnce in Development deparment because more than 70% employees travelling atleast 4 kms in this department...
# * Periodic Training are conducting in this department 90% employees attended atleast 2 training sessions.. 40% employees are dis-satisfied with Job Environment.
# * Salary hike for Grade 3 employees are low compared to other departments but a hike of 10 to 25 given to Grade 4 employees..
# * Attrition rate is also less in this department...
#
# #### Research and Development
# The second highest productive department in this company.
# * Most people  work as research scientist,R&D managers and Laboratary Technicians in this department..And a good percentage of them have a performance rating of 3 or higher
# * 80% of employees performing well in this department with rating of 3 and above..In research & development departemnt percentage of waek performers (Grade 2 employees) are equally high in all age groups
# * Grade 4 employees are high in Research scientist and Manager R&D job roles.
# * Weak performers recieved a hourly rate which is more than 70 in this department
# * A high dis-satisfaction among employees regarding the working environment and job is there..
# * Job involvement is high in this department but most weak performance is high in emoployees who have experience in the current role more than 4 years
# * Salary hike percentage seems to be reasonable and well addresed, most of the Grade 4 players recieved a hike of 20 to 25%
# * it can be understood that sufficient training has been conducted in the department,but its benefit is not fully recieved
#
# #### Sales
# This department have very high potential
# * The most important challenge in this department is Age of employees,performance was decreasing in employees with Age more than 35...
# * Sales executive and Sales representative are two major roles in this department,weak performers are high in sales executives..
# * Most of the employees have a education of bachelors or Masters,also employees from college education is also high in this department..
# * Training is in this department conducting timely but not that much beneficial to improve the performance...
# * Working environment and job dis_satisfaction percentage is high and most of the dis-satisfied employees got a rating of 2..
# * In Relationship wise 80% of employees satisfied moderatly or highly..But this satisfactional issues considerably affected the total sales performance..
# * Sales department has good experience employees but job involvement in this department high,but a 25% of employees job involvement is moderate or low.. This indicates department not fully analysing and utilizing the potential abilities of workforce efficiently..
# * Salary hike percentage is also low when compared to another departments ,most of the grade 3 employees received 10-15% hike and grade employees received 20 to 25%..
# * Attrition rate is also high in this department when comparing with other departments
#
# #### Human Resource
# * 81% employees performing well in this department
# * In HR department Grade 2 employees are high in 30 to 40 age group..Grade 4 employees are also less in numbers HR department
# * More than 60% Grade 2 employees recieved a high hourly rate of 91-100
# * Most of the weak performers only have a bachelors degree and most of the employees who only have education below college got a Grade of 4
# * Both Grade 2 and Grade 4 employees are highly disatisfied with working environment and also there is some Grade 3 employees not fully satisfied with thier job role..
# * Freshers are delivering good results with arating or 3 and 4
# * Although job involvement is 3 or more but weak perfomers rate is high in this group
# * Trainings are more usefull to this department,as the trend says as number quality training increases percentage of weak performers are decreasing
# * Salarfy hike is also seems to be reasonable ,Grade 4 employees recieved a good hike of more than 20%
#
# #### Finance
# * Out of total employees in Finanace department 30% of the are weak performers
# * Weak performers can be seen in all age group and the rate increasing when the age increases
# * A good percentage of Grade 2 employees recieved a hourly rate more than 70
# * Most of the weak performers only have a bachelors degree but 50% Grade 4 performers have only college level education
# * Weak performers are not satisfied with the working environment
# * There is a high dis satisfaction can be seen in Grade 4 and Grade 3 employees about relationship with employer
# * Employees mostly travelling more than 5kms(oneside) perday and the rate weak performers are increasing with the distance from home
# * Grade 4 employees have an experience of atleast 3..
# * The percentage of weak performers are low in employees who have attended a training of atleast 3
# * Attrition rate is also less in this department,but employees who leave the company are Grade 3 employees...
#
# #### Data Science
# * 93% of employees performing well in this department
# * Grade 4 employees are less in numbers from Data science department(6%)
# * Qualification of most of the employees are college level(certifications) and bachelor's
# * Employer relationship satisaction is low in this department
# * weak performers have an experience of more than 6years
# * Grade 4 performers are freshers and got a good hike 20 to 25%
# * 95% of employees attended ateast 2 trainings
